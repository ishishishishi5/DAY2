# %%
import sys
sys.path.append("/Users/ishimiwataru/Downloads/DNN_code_colab_lesson_1_2")
sys.path.append("/Users/ishimiwataru/Downloads/DNN_code_colab_lesson_1_2/lesson_2")

# %% [markdown]
# # deep convolution network

# %%
import pickle
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from common import optimizer

class DeepConvNet:
    '''
    認識率99%以上の高精度なConvNet

    conv - relu - conv- relu - pool -
    conv - relu - conv- relu - pool -
    conv - relu - conv- relu - pool -
    affine - relu - dropout - affine - dropout - softmax
    '''
    def __init__(self, input_dim=(1, 28, 28),
                 conv_param_1 = {'filter_num':16, 'filter_size':3, 'pad':1, 'stride':1},
                 conv_param_2 = {'filter_num':16, 'filter_size':3, 'pad':1, 'stride':1},
                 conv_param_3 = {'filter_num':32, 'filter_size':3, 'pad':1, 'stride':1},
                 conv_param_4 = {'filter_num':32, 'filter_size':3, 'pad':2, 'stride':1},
                 conv_param_5 = {'filter_num':64, 'filter_size':3, 'pad':1, 'stride':1},
                 conv_param_6 = {'filter_num':64, 'filter_size':3, 'pad':1, 'stride':1},
                 hidden_size=50, output_size=10):
        # 重みの初期化===========
        # 各層のニューロンひとつあたりが、前層のニューロンといくつのつながりがあるか
        pre_node_nums = np.array([1*3*3, 16*3*3, 16*3*3, 32*3*3, 32*3*3, 64*3*3, 64*4*4, hidden_size])
        wight_init_scales = np.sqrt(2.0 / pre_node_nums)  # Heの初期値
        
        self.params = {}
        pre_channel_num = input_dim[0]
        for idx, conv_param in enumerate([conv_param_1, conv_param_2, conv_param_3, conv_param_4, conv_param_5, conv_param_6]):
            self.params['W' + str(idx+1)] = wight_init_scales[idx] * np.random.randn(conv_param['filter_num'], pre_channel_num, conv_param['filter_size'], conv_param['filter_size'])
            self.params['b' + str(idx+1)] = np.zeros(conv_param['filter_num'])
            pre_channel_num = conv_param['filter_num']
        self.params['W7'] = wight_init_scales[6] * np.random.randn(pre_node_nums[6], hidden_size)
        print(self.params['W7'].shape)
        self.params['b7'] = np.zeros(hidden_size)
        self.params['W8'] = wight_init_scales[7] * np.random.randn(pre_node_nums[7], output_size)
        self.params['b8'] = np.zeros(output_size)

        # レイヤの生成===========
        self.layers = []
        self.layers.append(layers.Convolution(self.params['W1'], self.params['b1'], 
                           conv_param_1['stride'], conv_param_1['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Convolution(self.params['W2'], self.params['b2'], 
                           conv_param_2['stride'], conv_param_2['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Pooling(pool_h=2, pool_w=2, stride=2))
        self.layers.append(layers.Convolution(self.params['W3'], self.params['b3'], 
                           conv_param_3['stride'], conv_param_3['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Convolution(self.params['W4'], self.params['b4'],
                           conv_param_4['stride'], conv_param_4['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Pooling(pool_h=2, pool_w=2, stride=2))
        self.layers.append(layers.Convolution(self.params['W5'], self.params['b5'],
                           conv_param_5['stride'], conv_param_5['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Convolution(self.params['W6'], self.params['b6'],
                           conv_param_6['stride'], conv_param_6['pad']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Pooling(pool_h=2, pool_w=2, stride=2))
        self.layers.append(layers.Affine(self.params['W7'], self.params['b7']))
        self.layers.append(layers.Relu())
        self.layers.append(layers.Dropout(0.5))
        self.layers.append(layers.Affine(self.params['W8'], self.params['b8']))
        self.layers.append(layers.Dropout(0.5))
        
        self.last_layer = layers.SoftmaxWithLoss()

    def predict(self, x, train_flg=False):
        for layer in self.layers:
            if isinstance(layer, layers.Dropout):
                x = layer.forward(x, train_flg)
            else:
                x = layer.forward(x)
        return x

    def loss(self, x, d):
        y = self.predict(x, train_flg=True)
        return self.last_layer.forward(y, d)

    def accuracy(self, x, d, batch_size=100):
        if d.ndim != 1 : d = np.argmax(d, axis=1)

        acc = 0.0

        for i in range(int(x.shape[0] / batch_size)):
            tx = x[i*batch_size:(i+1)*batch_size]
            td = d[i*batch_size:(i+1)*batch_size]
            y = self.predict(tx, train_flg=False)
            y = np.argmax(y, axis=1)
            acc += np.sum(y == td)

        return acc / x.shape[0]

    def gradient(self, x, d):
        # forward
        self.loss(x, d)

        # backward
        dout = 1
        dout = self.last_layer.backward(dout)

        tmp_layers = self.layers.copy()
        tmp_layers.reverse()
        for layer in tmp_layers:
            dout = layer.backward(dout)

        # 設定
        grads = {}
        for i, layer_idx in enumerate((0, 2, 5, 7, 10, 12, 15, 18)):
            grads['W' + str(i+1)] = self.layers[layer_idx].dW
            grads['b' + str(i+1)] = self.layers[layer_idx].db

        return grads

# %%
(x_train, d_train), (x_test, d_test) = load_mnist(flatten=False)

# 処理に時間のかかる場合はデータを削減 
x_train, d_train = x_train[:5000], d_train[:5000]
x_test, d_test = x_test[:1000], d_test[:1000]

print("データ読み込み完了")

network = DeepConvNet()  
optimizer = optimizer.Adam()

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10


for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]
    
    grad = network.gradient(x_batch, d_batch)
    optimizer.update(network.params, grad)

    loss = network.loss(x_batch, d_batch)
    train_loss_list.append(loss)

    if (i+1) % plot_interval == 0:
        accr_train = network.accuracy(x_train, d_train)
        accr_test = network.accuracy(x_test, d_test)
        accuracies_train.append(accr_train)
        accuracies_test.append(accr_test)
        
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))               

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# (1024, 50)
# Generation: 10. 正答率(トレーニング) = 0.4818
#                 : 10. 正答率(テスト) = 0.436
# Generation: 20. 正答率(トレーニング) = 0.704
#                 : 20. 正答率(テスト) = 0.661
# Generation: 30. 正答率(トレーニング) = 0.7748
#                 : 30. 正答率(テスト) = 0.727
# Generation: 40. 正答率(トレーニング) = 0.8518
#                 : 40. 正答率(テスト) = 0.819
# Generation: 50. 正答率(トレーニング) = 0.902
#                 : 50. 正答率(テスト) = 0.875
# Generation: 60. 正答率(トレーニング) = 0.9024
#                 : 60. 正答率(テスト) = 0.874
# Generation: 70. 正答率(トレーニング) = 0.9218
#                 : 70. 正答率(テスト) = 0.909
# Generation: 80. 正答率(トレーニング) = 0.9348
#                 : 80. 正答率(テスト) = 0.921
# Generation: 90. 正答率(トレーニング) = 0.9368
#                 : 90. 正答率(テスト) = 0.909
# Generation: 100. 正答率(トレーニング) = 0.9454
#                 : 100. 正答率(テスト) = 0.918
# Generation: 110. 正答率(トレーニング) = 0.9484
#                 : 110. 正答率(テスト) = 0.932
# Generation: 120. 正答率(トレーニング) = 0.9478
#                 : 120. 正答率(テスト) = 0.924
# Generation: 130. 正答率(トレーニング) = 0.9558
#                 : 130. 正答率(テスト) = 0.927
# Generation: 140. 正答率(トレーニング) = 0.9588
#                 : 140. 正答率(テスト) = 0.932
# Generation: 150. 正答率(トレーニング) = 0.9656
#                 : 150. 正答率(テスト) = 0.94
# Generation: 160. 正答率(トレーニング) = 0.96
#                 : 160. 正答率(テスト) = 0.935
# Generation: 170. 正答率(トレーニング) = 0.9672
#                 : 170. 正答率(テスト) = 0.949
# Generation: 180. 正答率(トレーニング) = 0.9604
#                 : 180. 正答率(テスト) = 0.936
# Generation: 190. 正答率(トレーニング) = 0.9706
#                 : 190. 正答率(テスト) = 0.948
# Generation: 200. 正答率(トレーニング) = 0.9632
#                 : 200. 正答率(テスト) = 0.936
# Generation: 210. 正答率(トレーニング) = 0.969
#                 : 210. 正答率(テスト) = 0.948
# Generation: 220. 正答率(トレーニング) = 0.9708
#                 : 220. 正答率(テスト) = 0.951
# Generation: 230. 正答率(トレーニング) = 0.9682
#                 : 230. 正答率(テスト) = 0.942
# Generation: 240. 正答率(トレーニング) = 0.963
#                 : 240. 正答率(テスト) = 0.942
# Generation: 250. 正答率(トレーニング) = 0.9762
#                 : 250. 正答率(テスト) = 0.959
# Generation: 260. 正答率(トレーニング) = 0.9764
#                 : 260. 正答率(テスト) = 0.947
# Generation: 270. 正答率(トレーニング) = 0.9714
#                 : 270. 正答率(テスト) = 0.958
# Generation: 280. 正答率(トレーニング) = 0.9754
#                 : 280. 正答率(テスト) = 0.955
# Generation: 290. 正答率(トレーニング) = 0.971
#                 : 290. 正答率(テスト) = 0.951
# Generation: 300. 正答率(トレーニング) = 0.9738
#                 : 300. 正答率(テスト) = 0.953
# Generation: 310. 正答率(トレーニング) = 0.9762
#                 : 310. 正答率(テスト) = 0.956
# Generation: 320. 正答率(トレーニング) = 0.9784
#                 : 320. 正答率(テスト) = 0.962
# Generation: 330. 正答率(トレーニング) = 0.9786
#                 : 330. 正答率(テスト) = 0.965
# Generation: 340. 正答率(トレーニング) = 0.9768
#                 : 340. 正答率(テスト) = 0.962
# Generation: 350. 正答率(トレーニング) = 0.98
#                 : 350. 正答率(テスト) = 0.967
# Generation: 360. 正答率(トレーニング) = 0.9778
#                 : 360. 正答率(テスト) = 0.954
# Generation: 370. 正答率(トレーニング) = 0.98
#                 : 370. 正答率(テスト) = 0.962
# Generation: 380. 正答率(トレーニング) = 0.9788
#                 : 380. 正答率(テスト) = 0.964
# Generation: 390. 正答率(トレーニング) = 0.9796
#                 : 390. 正答率(テスト) = 0.954
# Generation: 400. 正答率(トレーニング) = 0.9842
#                 : 400. 正答率(テスト) = 0.964
# Generation: 410. 正答率(トレーニング) = 0.982
#                 : 410. 正答率(テスト) = 0.963
# Generation: 420. 正答率(トレーニング) = 0.9852
#                 : 420. 正答率(テスト) = 0.965
# Generation: 430. 正答率(トレーニング) = 0.982
#                 : 430. 正答率(テスト) = 0.967
# Generation: 440. 正答率(トレーニング) = 0.9846
#                 : 440. 正答率(テスト) = 0.964
# Generation: 450. 正答率(トレーニング) = 0.9858
#                 : 450. 正答率(テスト) = 0.967
# Generation: 460. 正答率(トレーニング) = 0.9842
#                 : 460. 正答率(テスト) = 0.959
# Generation: 470. 正答率(トレーニング) = 0.9834
#                 : 470. 正答率(テスト) = 0.963
# Generation: 480. 正答率(トレーニング) = 0.9826
#                 : 480. 正答率(テスト) = 0.968
# Generation: 490. 正答率(トレーニング) = 0.9852
#                 : 490. 正答率(テスト) = 0.959
# Generation: 500. 正答率(トレーニング) = 0.9794
#                 : 500. 正答率(テスト) = 0.962
# Generation: 510. 正答率(トレーニング) = 0.9844
#                 : 510. 正答率(テスト) = 0.961
# Generation: 520. 正答率(トレーニング) = 0.9854
#                 : 520. 正答率(テスト) = 0.967
# Generation: 530. 正答率(トレーニング) = 0.9832
#                 : 530. 正答率(テスト) = 0.968
# Generation: 540. 正答率(トレーニング) = 0.9874
#                 : 540. 正答率(テスト) = 0.968
# Generation: 550. 正答率(トレーニング) = 0.9858
#                 : 550. 正答率(テスト) = 0.967
# Generation: 560. 正答率(トレーニング) = 0.9868
#                 : 560. 正答率(テスト) = 0.971
# Generation: 570. 正答率(トレーニング) = 0.9886
#                 : 570. 正答率(テスト) = 0.971
# Generation: 580. 正答率(トレーニング) = 0.9872
#                 : 580. 正答率(テスト) = 0.967
# Generation: 590. 正答率(トレーニング) = 0.9886
#                 : 590. 正答率(テスト) = 0.968
# Generation: 600. 正答率(トレーニング) = 0.9876
#                 : 600. 正答率(テスト) = 0.961
# Generation: 610. 正答率(トレーニング) = 0.9896
#                 : 610. 正答率(テスト) = 0.967
# Generation: 620. 正答率(トレーニング) = 0.982
#                 : 620. 正答率(テスト) = 0.951
# Generation: 630. 正答率(トレーニング) = 0.989
#                 : 630. 正答率(テスト) = 0.965
# Generation: 640. 正答率(トレーニング) = 0.9898
#                 : 640. 正答率(テスト) = 0.967
# Generation: 650. 正答率(トレーニング) = 0.9892
#                 : 650. 正答率(テスト) = 0.975
# Generation: 660. 正答率(トレーニング) = 0.9894
#                 : 660. 正答率(テスト) = 0.971
# Generation: 670. 正答率(トレーニング) = 0.9872
#                 : 670. 正答率(テスト) = 0.97
# Generation: 680. 正答率(トレーニング) = 0.9832
#                 : 680. 正答率(テスト) = 0.963
# Generation: 690. 正答率(トレーニング) = 0.9926
#                 : 690. 正答率(テスト) = 0.979
# Generation: 700. 正答率(トレーニング) = 0.9918
#                 : 700. 正答率(テスト) = 0.977
# Generation: 710. 正答率(トレーニング) = 0.9914
#                 : 710. 正答率(テスト) = 0.972
# Generation: 720. 正答率(トレーニング) = 0.9908
#                 : 720. 正答率(テスト) = 0.975
# Generation: 730. 正答率(トレーニング) = 0.9916
#                 : 730. 正答率(テスト) = 0.97
# Generation: 740. 正答率(トレーニング) = 0.9902
#                 : 740. 正答率(テスト) = 0.972
# Generation: 750. 正答率(トレーニング) = 0.9942
#                 : 750. 正答率(テスト) = 0.978
# Generation: 760. 正答率(トレーニング) = 0.9912
#                 : 760. 正答率(テスト) = 0.98
# Generation: 770. 正答率(トレーニング) = 0.9918
#                 : 770. 正答率(テスト) = 0.976
# Generation: 780. 正答率(トレーニング) = 0.9936
#                 : 780. 正答率(テスト) = 0.981
# Generation: 790. 正答率(トレーニング) = 0.9936
#                 : 790. 正答率(テスト) = 0.983
# Generation: 800. 正答率(トレーニング) = 0.9932
#                 : 800. 正答率(テスト) = 0.979
# Generation: 810. 正答率(トレーニング) = 0.9912
#                 : 810. 正答率(テスト) = 0.972
# Generation: 820. 正答率(トレーニング) = 0.9912
#                 : 820. 正答率(テスト) = 0.973
# Generation: 830. 正答率(トレーニング) = 0.9936
#                 : 830. 正答率(テスト) = 0.977
# Generation: 840. 正答率(トレーニング) = 0.9938
#                 : 840. 正答率(テスト) = 0.984
# Generation: 850. 正答率(トレーニング) = 0.9936
#                 : 850. 正答率(テスト) = 0.979
# Generation: 860. 正答率(トレーニング) = 0.9934
#                 : 860. 正答率(テスト) = 0.982
# Generation: 870. 正答率(トレーニング) = 0.991
#                 : 870. 正答率(テスト) = 0.975
# Generation: 880. 正答率(トレーニング) = 0.9936
#                 : 880. 正答率(テスト) = 0.975
# Generation: 890. 正答率(トレーニング) = 0.9952
#                 : 890. 正答率(テスト) = 0.977
# Generation: 900. 正答率(トレーニング) = 0.9948
#                 : 900. 正答率(テスト) = 0.979
# Generation: 910. 正答率(トレーニング) = 0.9944
#                 : 910. 正答率(テスト) = 0.975
# Generation: 920. 正答率(トレーニング) = 0.9944
#                 : 920. 正答率(テスト) = 0.975
# Generation: 930. 正答率(トレーニング) = 0.9958
#                 : 930. 正答率(テスト) = 0.978
# Generation: 940. 正答率(トレーニング) = 0.9968
#                 : 940. 正答率(テスト) = 0.982
# Generation: 950. 正答率(トレーニング) = 0.9954
#                 : 950. 正答率(テスト) = 0.981
# Generation: 960. 正答率(トレーニング) = 0.992
#                 : 960. 正答率(テスト) = 0.973
# Generation: 970. 正答率(トレーニング) = 0.9954
#                 : 970. 正答率(テスト) = 0.981
# Generation: 980. 正答率(トレーニング) = 0.995
#                 : 980. 正答率(テスト) = 0.983
# Generation: 990. 正答率(トレーニング) = 0.9952
#                 : 990. 正答率(テスト) = 0.98
# Generation: 1000. 正答率(トレーニング) = 0.9962
#                 : 1000. 正答率(テスト) = 0.983
